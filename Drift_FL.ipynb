# %% [markdown]
# <a href="https://colab.research.google.com/github/Raksh-iscool/driftfl/blob/main/Drift_FL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   # !pip install torch torchvision numpy scipy matplotlib

# %%
# !python sketch.py
# Out:
# === Count-Min Sketch Test ===
# Query 42 (true=100): 100
# Query 99 (true=50):  50
# Query 7  (true=10):  10
# Query 0  (true=0):   0
#
# === Feature Sketch Bank Test ===
# Tables shape: (4, 5, 64)
# Total counts per feature: [np.int64(100), np.int64(100), np.int64(100), np.int64(100)]
# Tests passed.

# %%
# !python drift_scorer.py
# Out:
# === Drift Scorer Tests ===
# Same dist score: 0.1306 (should be low)
# Diff dist score: 162.0756 (should be higher)
# Severity: 1, Phi: 0.15, Flagged: 3/20
#
# === DriftMonitor Lifecycle ===
# Round 1: warmup=True, severity=0
# Round 2: warmup=True, severity=0
# Round 3: warmup=True, severity=0
# Round 4: warmup=False, severity=0, phi=0.000
# Round 5: warmup=False, severity=2, phi=1.000
#
# All tests passed.

# %%
# !python models.py
# Out:
# === Model Architecture Tests ===
# CIFAR ResNet-18:
#   Feature dim: 512
#   Feature shape: torch.Size([4, 512])
#   Output shape: torch.Size([4, 100])
#   Parameters: 11,220,132
#   Model size: 44.88 MB
#
# Synthetic MLP:
#   Feature dim: 64
#   Feature shape: torch.Size([4, 64])
#   Output shape: torch.Size([4, 1])
#   Parameters: 46,593
#   Model size: 0.19 MB

# %%
# !python run_experiment.py --task synthetic --method fedavg --seed 42 --device cuda
# Out:
# ...
# Task: synthetic | Method: fedavg | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 1.6s | Sev: [5/0/0]
#   Round  10 | Acc: 97.87% | Time: 1.0s | Sev: [5/0/0]
#   Round  20 | Acc: 98.22% | Time: 0.8s | Sev: [5/0/0]
#   Round  30 | Acc: 98.35% | Time: 0.8s | Sev: [5/0/0]
#   Round  40 | Acc: 98.43% | Time: 0.9s | Sev: [5/0/0]
#   Round  50 | Acc: 98.50% | Time: 0.8s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 0.8s | Sev: [5/0/0]
#   Round  70 | Acc: 44.45% | Time: 0.8s | Sev: [5/0/0]
#   Round  80 | Acc: 0.00% | Time: 0.8s | Sev: [5/0/0]
#   Round  90 | Acc: 39.74% | Time: 0.8s | Sev: [5/0/0]
#   Round 100 | Acc: 98.04% | Time: 0.8s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedavg_seed42.csv
#
#   Final Accuracy: 98.04%
#   Avg Post-Drift Accuracy: 55.58%

# %%
# !python run_experiment.py --task synthetic --method fedavg --seed 42
# Out:
# ...
# Task: synthetic | Method: fedavg | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 1.2s | Sev: [5/0/0]
#   Round  10 | Acc: 97.87% | Time: 0.9s | Sev: [5/0/0]
#   Round  20 | Acc: 98.22% | Time: 0.8s | Sev: [5/0/0]
#   Round  30 | Acc: 98.35% | Time: 0.8s | Sev: [5/0/0]
#   Round  40 | Acc: 98.43% | Time: 0.8s | Sev: [5/0/0]
#   Round  50 | Acc: 98.50% | Time: 0.8s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 0.8s | Sev: [5/0/0]
#   Round  70 | Acc: 44.45% | Time: 0.8s | Sev: [5/0/0]
#   Round  80 | Acc: 0.00% | Time: 0.8s | Sev: [5/0/0]
#   Round  90 | Acc: 39.74% | Time: 0.8s | Sev: [5/0/0]
#   Round 100 | Acc: 98.04% | Time: 0.8s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedavg_seed42.csv
#
#   Final Accuracy: 98.04%
#   Avg Post-Drift Accuracy: 55.58%

# %%
# !python run_experiment.py --task synthetic --method fedprox --seed 42
# Out:
# ...
# Task: synthetic | Method: fedprox | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 2.0s | Sev: [5/0/0]
#   Round  10 | Acc: 97.87% | Time: 1.4s | Sev: [5/0/0]
#   Round  20 | Acc: 98.22% | Time: 1.6s | Sev: [5/0/0]
#   Round  30 | Acc: 98.33% | Time: 1.6s | Sev: [5/0/0]
#   Round  40 | Acc: 98.42% | Time: 1.3s | Sev: [5/0/0]
#   Round  50 | Acc: 98.50% | Time: 1.3s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 1.3s | Sev: [5/0/0]
#   Round  70 | Acc: 45.07% | Time: 1.3s | Sev: [5/0/0]
#   Round  80 | Acc: 0.00% | Time: 1.3s | Sev: [5/0/0]
#   Round  90 | Acc: 39.84% | Time: 1.3s | Sev: [5/0/0]
#   Round 100 | Acc: 98.00% | Time: 1.3s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedprox_seed42.csv
#
#   Final Accuracy: 98.00%
#   Avg Post-Drift Accuracy: 55.99%

# %%
# !python run_experiment.py --task synthetic --method driftfl --seed 42
# Out:
# ...
# Task: synthetic | Method: driftfl | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 3.1s | Sev: [5/0/0]
#   Round  10 | Acc: 97.87% | Time: 2.9s | Sev: [5/0/0]
#   Round  20 | Acc: 98.22% | Time: 3.7s | Sev: [5/0/0]
#   Round  30 | Acc: 98.35% | Time: 2.7s | Sev: [5/0/0]
#   Round  40 | Acc: 98.43% | Time: 2.8s | Sev: [5/0/0]
#   Round  50 | Acc: 98.50% | Time: 2.8s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 2.8s | Sev: [4/1/0]
#   Round  70 | Acc: 21.06% | Time: 2.9s | Sev: [3/2/0]
#   Round  80 | Acc: 0.00% | Time: 3.0s | Sev: [2/3/0]
#   Round  90 | Acc: 0.00% | Time: 3.0s | Sev: [2/3/0]
#   Round 100 | Acc: 97.91% | Time: 3.8s | Sev: [2/3/0]
# Saved round results to results/synthetic_driftfl_seed42.csv
#
#   Final Accuracy: 97.91%
#   Avg Post-Drift Accuracy: 48.16%
#   Avg Detection Latency: 12.0 rounds

# %%
# !python run_experiment.py --task cifar100 --method fedavg --seed 42
# Out:
# ...
# Task: cifar100 | Method: fedavg | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
# 100% 169M/169M [00:04<00:00, 41.9MB/s]
#   Round   1 | Acc: 3.00% | Time: 33.3s | Sev: [10/0/0]
# Traceback (most recent call last):
# object address  : 0x7b4a72621de0
# object refcount : 3
# object type     : 0xa284e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C

# %%
# !python run_experiment.py --run-all --device cuda
# Out:
# ...
# Task: cifar100 | Method: fedavg | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
#   Round   1 | Acc: 2.99% | Time: 33.4s | Sev: [10/0/0]
#   Round  10 | Acc: 23.07% | Time: 32.7s | Sev: [10/0/0]
# Traceback (most recent call last):
#   File "/content/run_experiment.py", line 280, in <module>
#     main()
#   File "/content/run_experiment.py", line 274, in main
#     run_all_experiments(device, args.results_dir)
#   File "/content/run_experiment.py", line 229, in run_all_experiments
#     summary = run_experiment(task, method, seed, device, results_dir)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/run_experiment.py", line 124, in run_experiment
#     result = clients[k].fit(global_state, rnd)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/client.py", line 213, in fit
#     avg_loss = train_local(
#                ^^^^^^^^^^^^
#   File "/content/client.py", line 70, in train_local
#     for batch_data in dataloader:
# ...

# %%
#sample

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/driftfl_code
# Out:
# /content/drive/MyDrive/driftfl_code

# %%
# !ls
# Out:
# client.py	     data_utils.py    plot_results.py  run_experiment.py
# CONFERENCE_GUIDE.md  drift_scorer.py  __pycache__      server.py
# config.py	     models.py	      README.md        sketch.py
# data		     output.log       results

# %%
   # !pip install torch torchvision numpy scipy matplotlib

# %%
# !python sketch.py
# Out:
# === Count-Min Sketch Test ===
# Query 42 (true=100): 100
# Query 99 (true=50):  50
# Query 7  (true=10):  10
# Query 0  (true=0):   0
#
# === Feature Sketch Bank Test ===
# Tables shape: (4, 5, 64)
# Total counts per feature: [np.int64(100), np.int64(100), np.int64(100), np.int64(100)]
# Tests passed.

# %%
# !python drift_scorer.py
# Out:
# === Drift Scorer Tests ===
# Same dist score: 0.1306 (should be low)
# Diff dist score: 162.0756 (should be higher)
# Severity: 1, Phi: 0.15, Flagged: 3/20
#
# === DriftMonitor Lifecycle ===
# Round 1: warmup=True, severity=0
# Round 2: warmup=True, severity=0
# Round 3: warmup=True, severity=0
# Round 4: warmup=False, severity=0, phi=0.000
# Round 5: warmup=False, severity=2, phi=1.000
#
# All tests passed.

# %%
# !python models.py
# Out:
# === Model Architecture Tests ===
# CIFAR ResNet-18:
#   Feature dim: 512
#   Feature shape: torch.Size([4, 512])
#   Output shape: torch.Size([4, 100])
#   Parameters: 11,220,132
#   Model size: 44.88 MB
#
# Synthetic MLP:
#   Feature dim: 64
#   Feature shape: torch.Size([4, 64])
#   Output shape: torch.Size([4, 1])
#   Parameters: 46,593
#   Model size: 0.19 MB

# %%
# !python run_experiment.py --task synthetic --method fedavg --seed 43 --device cuda
# Out:
# ...
# Task: synthetic | Method: fedavg | Seed: 43
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 1.6s | Sev: [5/0/0]
#   Round  10 | Acc: 98.23% | Time: 1.1s | Sev: [5/0/0]
#   Round  20 | Acc: 98.51% | Time: 0.9s | Sev: [5/0/0]
#   Round  30 | Acc: 98.62% | Time: 0.8s | Sev: [5/0/0]
#   Round  40 | Acc: 98.66% | Time: 1.0s | Sev: [5/0/0]
#   Round  50 | Acc: 0.00% | Time: 0.8s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 0.8s | Sev: [5/0/0]
#   Round  70 | Acc: 8.04% | Time: 1.0s | Sev: [5/0/0]
#   Round  80 | Acc: 98.13% | Time: 0.9s | Sev: [5/0/0]
#   Round  90 | Acc: 0.00% | Time: 0.9s | Sev: [5/0/0]
#   Round 100 | Acc: 0.00% | Time: 0.9s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedavg_seed43.csv
#
#   Final Accuracy: 0.00%
#   Avg Post-Drift Accuracy: 35.30%

# %%
# !python run_experiment.py --task synthetic --method fedprox --seed 43
# Out:
# ...
# Task: synthetic | Method: fedprox | Seed: 43
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 2.1s | Sev: [5/0/0]
#   Round  10 | Acc: 98.25% | Time: 1.4s | Sev: [5/0/0]
#   Round  20 | Acc: 98.55% | Time: 1.5s | Sev: [5/0/0]
#   Round  30 | Acc: 98.63% | Time: 1.6s | Sev: [5/0/0]
#   Round  40 | Acc: 98.66% | Time: 1.7s | Sev: [5/0/0]
#   Round  50 | Acc: 2.99% | Time: 1.8s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 1.7s | Sev: [5/0/0]
#   Round  70 | Acc: 7.86% | Time: 1.6s | Sev: [5/0/0]
#   Round  80 | Acc: 98.17% | Time: 1.4s | Sev: [5/0/0]
#   Round  90 | Acc: 0.00% | Time: 1.5s | Sev: [5/0/0]
#   Round 100 | Acc: 1.81% | Time: 1.3s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedprox_seed43.csv
#
#   Final Accuracy: 1.81%
#   Avg Post-Drift Accuracy: 35.36%

# %%
# !python run_experiment.py --task synthetic --method driftfl --seed 43
# Out:
# ...
# Task: synthetic | Method: driftfl | Seed: 43
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 3.2s | Sev: [5/0/0]
#   Round  10 | Acc: 96.13% | Time: 2.7s | Sev: [5/0/0]
#   Round  20 | Acc: 96.62% | Time: 3.2s | Sev: [5/0/0]
#   Round  30 | Acc: 96.96% | Time: 4.2s | Sev: [5/0/0]
#   Round  40 | Acc: 97.46% | Time: 2.7s | Sev: [5/0/0]
#   Round  50 | Acc: 0.00% | Time: 2.7s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 3.0s | Sev: [5/0/0]
#   Round  70 | Acc: 38.25% | Time: 3.5s | Sev: [5/0/0]
#   Round  80 | Acc: 97.07% | Time: 3.1s | Sev: [5/0/0]
#   Round  90 | Acc: 18.47% | Time: 3.8s | Sev: [5/0/0]
#   Round 100 | Acc: 30.31% | Time: 3.1s | Sev: [5/0/0]
# Saved round results to results/synthetic_driftfl_seed43.csv
#
#   Final Accuracy: 30.31%
#   Avg Post-Drift Accuracy: 46.62%

# %%
# !python run_experiment.py --task synthetic --method driftfl --seed 43
# Out:
# ...
# Task: synthetic | Method: driftfl | Seed: 43
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 3.2s | Sev: [5/0/0]
#   Round  10 | Acc: 96.13% | Time: 2.6s | Sev: [5/0/0]
#   Round  20 | Acc: 96.62% | Time: 2.5s | Sev: [5/0/0]
#   Round  30 | Acc: 96.96% | Time: 2.6s | Sev: [5/0/0]
#   Round  40 | Acc: 97.46% | Time: 3.9s | Sev: [5/0/0]
#   Round  50 | Acc: 0.00% | Time: 3.7s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 2.9s | Sev: [5/0/0]
#   Round  70 | Acc: 38.25% | Time: 2.9s | Sev: [5/0/0]
#   Round  80 | Acc: 97.07% | Time: 3.7s | Sev: [5/0/0]
#   Round  90 | Acc: 18.47% | Time: 3.0s | Sev: [5/0/0]
#   Round 100 | Acc: 30.31% | Time: 4.7s | Sev: [5/0/0]
# Saved round results to results/synthetic_driftfl_seed43.csv
#
#   Final Accuracy: 30.31%
#   Avg Post-Drift Accuracy: 46.62%

# %%
#SEED 42

# %%
# !python run_experiment.py --task synthetic --method fedavg --seed 42 --device cuda
# Out:
# ...
# Task: synthetic | Method: fedavg | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 1.0s | Sev: [5/0/0]
#   Round  10 | Acc: 95.28% | Time: 0.4s | Sev: [5/0/0]
#   Round  20 | Acc: 96.06% | Time: 0.4s | Sev: [5/0/0]
#   Round  30 | Acc: 96.54% | Time: 0.3s | Sev: [5/0/0]
#   Round  40 | Acc: 96.64% | Time: 0.4s | Sev: [5/0/0]
#   Round  50 | Acc: 97.30% | Time: 0.4s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 0.4s | Sev: [5/0/0]
#   Round  70 | Acc: 56.82% | Time: 0.5s | Sev: [5/0/0]
#   Round  80 | Acc: 0.00% | Time: 0.4s | Sev: [5/0/0]
#   Round  90 | Acc: 52.28% | Time: 0.4s | Sev: [5/0/0]
#   Round 100 | Acc: 96.46% | Time: 0.4s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedavg_seed42.csv
#
#   Final Accuracy: 96.46%
#   Avg Post-Drift Accuracy: 57.08%

# %%
# !python run_experiment.py --task synthetic --method fedprox --seed 42
# Out:
# ...
# Task: synthetic | Method: fedprox | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 1.0s | Sev: [5/0/0]
#   Round  10 | Acc: 95.28% | Time: 0.8s | Sev: [5/0/0]
#   Round  20 | Acc: 96.04% | Time: 0.7s | Sev: [5/0/0]
#   Round  30 | Acc: 96.53% | Time: 0.9s | Sev: [5/0/0]
#   Round  40 | Acc: 96.64% | Time: 0.6s | Sev: [5/0/0]
#   Round  50 | Acc: 97.29% | Time: 0.7s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 0.5s | Sev: [5/0/0]
#   Round  70 | Acc: 56.78% | Time: 0.6s | Sev: [5/0/0]
#   Round  80 | Acc: 0.00% | Time: 0.6s | Sev: [5/0/0]
#   Round  90 | Acc: 51.86% | Time: 0.6s | Sev: [5/0/0]
#   Round 100 | Acc: 96.45% | Time: 0.6s | Sev: [5/0/0]
# Saved round results to results/synthetic_fedprox_seed42.csv
#
#   Final Accuracy: 96.45%
#   Avg Post-Drift Accuracy: 56.96%

# %%
# !python run_experiment.py --task synthetic --method driftfl --seed 42
# Out:
# ...
# Task: synthetic | Method: driftfl | Seed: 42
# ...
# Model: 46,593 params, 0.19 MB
#   Round   1 | Acc: 0.00% | Time: 3.3s | Sev: [5/0/0]
#   Round  10 | Acc: 95.28% | Time: 2.7s | Sev: [5/0/0]
#   Round  20 | Acc: 96.06% | Time: 2.7s | Sev: [5/0/0]
#   Round  30 | Acc: 96.54% | Time: 2.7s | Sev: [5/0/0]
#   Round  40 | Acc: 96.64% | Time: 2.9s | Sev: [5/0/0]
#   Round  50 | Acc: 97.30% | Time: 4.1s | Sev: [5/0/0]
#   Round  60 | Acc: 0.00% | Time: 2.8s | Sev: [5/0/0]
#   Round  70 | Acc: 45.76% | Time: 2.9s | Sev: [4/1/0]
#   Round  80 | Acc: 0.00% | Time: 3.9s | Sev: [4/1/0]
#   Round  90 | Acc: 22.43% | Time: 3.1s | Sev: [3/1/1]
#   Round 100 | Acc: 96.10% | Time: 3.7s | Sev: [3/1/1]
# Saved round results to results/synthetic_driftfl_seed42.csv
#
#   Final Accuracy: 96.10%
#   Avg Post-Drift Accuracy: 52.46%

# %%
# !python -c "import torch; print(torch.cuda.is_available())"
# Out:
# True

# %%
# !python run_experiment.py --run-all --device cuda | tee output.log
# Out:
# ...
# Task: cifar100 | Method: fedavg | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
# 100% 169M/169M [00:05<00:00, 31.5MB/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 280, in <module>
#     main()
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 274, in main
#     run_all_experiments(device, args.results_dir)
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 229, in run_all_experiments
#     summary = run_experiment(task, method, seed, device, results_dir)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 124, in run_experiment
#     result = clients[k].fit(global_state, rnd)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/driftfl_code/client.py", line 213, in fit
#     avg_loss = train_local(
#                ^^^^^^^^^^^^
# ...

# %%
# !python run_experiment.py --task cifar100 --method driftfl --seed 42
# Out:
# ...
# Task: cifar100 | Method: driftfl | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
#   Round   1 | Acc: 1.24% | Time: 45.6s | Sev: [10/0/0]
#   Round  10 | Acc: 12.60% | Time: 42.3s | Sev: [10/0/0]
#   Round  20 | Acc: 15.80% | Time: 76.2s | Sev: [10/0/0]
#   Round  30 | Acc: 18.02% | Time: 43.6s | Sev: [10/0/0]
#   Round  40 | Acc: 19.16% | Time: 42.4s | Sev: [10/0/0]
#   Round  50 | Acc: 21.49% | Time: 42.1s | Sev: [10/0/0]
#   Round  60 | Acc: 22.79% | Time: 44.7s | Sev: [10/0/0]
#   Round  70 | Acc: 23.23% | Time: 43.0s | Sev: [10/0/0]
#   Round  80 | Acc: 28.48% | Time: 43.0s | Sev: [10/0/0]
#   Round  90 | Acc: 29.92% | Time: 43.8s | Sev: [10/0/0]
#   Round 100 | Acc: 32.94% | Time: 43.6s | Sev: [9/1/0]
# Saved round results to results/cifar100_driftfl_seed42.csv
#
#   Final Accuracy: 32.94%
#   Avg Post-Drift Accuracy: 26.10%

# %%
# !python run_experiment.py --task cifar100 --method fedavg --seed 42
# Out:
# ...
# Task: cifar100 | Method: fedavg | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
#   Round   1 | Acc: 1.22% | Time: 18.8s | Sev: [10/0/0]
#   Round  10 | Acc: 12.61% | Time: 18.4s | Sev: [10/0/0]
#   Round  20 | Acc: 15.00% | Time: 29.1s | Sev: [10/0/0]
#   Round  30 | Acc: 17.66% | Time: 17.8s | Sev: [10/0/0]
#   Round  40 | Acc: 18.91% | Time: 18.1s | Sev: [10/0/0]
#   Round  50 | Acc: 21.14% | Time: 17.2s | Sev: [10/0/0]
#   Round  60 | Acc: 22.40% | Time: 18.4s | Sev: [10/0/0]
#   Round  70 | Acc: 23.27% | Time: 18.0s | Sev: [10/0/0]
#   Round  80 | Acc: 28.14% | Time: 18.7s | Sev: [10/0/0]
#   Round  90 | Acc: 30.85% | Time: 18.5s | Sev: [10/0/0]
#   Round 100 | Acc: 33.06% | Time: 18.9s | Sev: [10/0/0]
# Saved round results to results/cifar100_fedavg_seed42.csv
#
#   Final Accuracy: 33.06%
#   Avg Post-Drift Accuracy: 26.19%

# %%
#old code

# %%
# !python run_experiment.py --task cifar100 --method driftfl --seed 42
# Out:
# ...
# Task: cifar100 | Method: driftfl | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
#   Round   1 | Acc: 2.87% | Time: 59.2s | Sev: [10/0/0]
#   Round  10 | Acc: 23.09% | Time: 57.0s | Sev: [10/0/0]
#   Round  20 | Acc: 30.48% | Time: 103.4s | Sev: [10/0/0]
#   Round  30 | Acc: 37.62% | Time: 58.4s | Sev: [10/0/0]
#   Round  40 | Acc: 40.28% | Time: 59.2s | Sev: [10/0/0]
#   Round  50 | Acc: 42.98% | Time: 54.7s | Sev: [10/0/0]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 280, in <module>
#     main()
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 276, in main
#     run_experiment(args.task, args.method, args.seed, device, args.results_dir)
#   File "/content/drive/MyDrive/driftfl_code/run_experiment.py", line 124, in run_experiment
#     result = clients[k].fit(global_state, rnd)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python run_experiment.py --task cifar100 --method driftfl --seed 42
# Out:
# python3: can't open file '/content/run_experiment.py': [Errno 2] No such file or directory

# %%
# !python run_experiment.py --task cifar100 --method driftfl --seed 42
# Out:
# ...
# Task: cifar100 | Method: driftfl | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
#   Round   1 | Acc: 2.89% | Time: 59.3s | Sev: [10/0/0]
#   Round  10 | Acc: 22.86% | Time: 58.6s | Sev: [10/0/0]
#   Round  20 | Acc: 30.31% | Time: 102.3s | Sev: [10/0/0]
#   Round  30 | Acc: 37.04% | Time: 59.3s | Sev: [10/0/0]
#   Round  40 | Acc: 38.27% | Time: 60.2s | Sev: [10/0/0]
#   Round  50 | Acc: 43.08% | Time: 54.7s | Sev: [10/0/0]
#   Round  60 | Acc: 45.81% | Time: 59.2s | Sev: [10/0/0]
#   Round  70 | Acc: 46.24% | Time: 57.5s | Sev: [10/0/0]
#   Round  80 | Acc: 49.22% | Time: 59.5s | Sev: [10/0/0]
#   Round  90 | Acc: 50.18% | Time: 61.5s | Sev: [10/0/0]
#   Round 100 | Acc: 52.42% | Time: 56.5s | Sev: [10/0/0]
# Saved round results to results/cifar100_driftfl_seed42.csv
#
#   Final Accuracy: 52.42%
#   Avg Post-Drift Accuracy: 47.72%

# %%
# !python run_experiment.py --task cifar100 --method fedavg --seed 42
# Out:
# ...
# Task: cifar100 | Method: fedavg | Seed: 42
# ...
# Model: 11,220,132 params, 44.88 MB
#   Round   1 | Acc: 3.24% | Time: 35.6s | Sev: [10/0/0]
#   Round  10 | Acc: 22.60% | Time: 33.1s | Sev: [10/0/0]
#   Round  20 | Acc: 30.36% | Time: 59.5s | Sev: [10/0/0]
#   Round  30 | Acc: 37.67% | Time: 33.5s | Sev: [10/0/0]
#   Round  40 | Acc: 39.46% | Time: 34.2s | Sev: [10/0/0]
#   Round  50 | Acc: 43.47% | Time: 32.1s | Sev: [10/0/0]
#   Round  60 | Acc: 45.55% | Time: 34.8s | Sev: [10/0/0]
#   Round  70 | Acc: 46.83% | Time: 33.6s | Sev: [10/0/0]
#   Round  80 | Acc: 50.08% | Time: 34.0s | Sev: [10/0/0]
#   Round  90 | Acc: 50.44% | Time: 35.0s | Sev: [10/0/0]
#   Round 100 | Acc: 52.09% | Time: 33.9s | Sev: [10/0/0]
# Saved round results to results/cifar100_fedavg_seed42.csv
#
#   Final Accuracy: 52.09%
#   Avg Post-Drift Accuracy: 47.85%
